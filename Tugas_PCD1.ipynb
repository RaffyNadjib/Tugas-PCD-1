# %% [markdown]
# <a href="https://colab.research.google.com/github/RaffyNadjib/Tugas-PCD-1/blob/main/Tugas_PCD1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt


img = cv2.imread('/content/bg.png')
img = cv2.imread('/content/bg.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
# plt.imshow(img)
plt.title('Citra Asli (Grayscale)')
plt.show()
