# %% [markdown]
# <a href="https://colab.research.google.com/github/RaffyNadjib/Tugas-PCD-Per2/blob/main/Soal_2_PCD_Per2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# Pastikan nama file sesuai dengan yang kamu upload
img = cv2.imread("bg.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

sizes = [512, 256, 128, 64]

plt.figure(figsize=(10,8))

for i, s in enumerate(sizes):
    resized = cv2.resize(img, (s, s))
    plt.subplot(2,2,i+1)
    plt.imshow(resized)
    plt.title(f"{s} x {s}")
    plt.axis("off")

plt.tight_layout()
plt.show()
